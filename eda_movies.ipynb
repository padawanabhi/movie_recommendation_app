# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ratings = pd.read_csv('./data/ratings_matrix_original.csv', index_col=0)

# %%
ratings.head()
# Out:
#         '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
#         'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
#         'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# ...

# %%
new_rating = ratings.loc[ratings.T.notna().sum().sort_values(ascending=False) > 75]

# %%
new_rating.head()
# Out:
#         '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 4              NaN                                      NaN
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 10             NaN                                      NaN
#
#         'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 4                          NaN                  NaN
# 6                          NaN                  NaN
# 7                          NaN                  NaN
# 10                         NaN                  NaN
#
#         'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 4                             NaN                              NaN
# ...

# %%
new_rating.head()
# Out:
#         '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 4              NaN                                      NaN
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 10             NaN                                      NaN
#
#         'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 4                          NaN                  NaN
# 6                          NaN                  NaN
# 7                          NaN                  NaN
# 10                         NaN                  NaN
#
#         'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 4                             NaN                              NaN
# ...

# %%
new_rating.shape
# Out:
# (295, 9719)

# %%
list(new_rating.notna().sum().sort_values(ascending=False).index[:10])
# Out:
# ['Forrest Gump (1994)',
#  'Pulp Fiction (1994)',
#  'Matrix, The (1999)',
#  'Shawshank Redemption, The (1994)',
#  'Silence of the Lambs, The (1991)',
#  'Star Wars: Episode IV - A New Hope (1977)',
#  'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'Jurassic Park (1993)',
#  'Fight Club (1999)',
#  'Toy Story (1995)']

# %%
new_rating.mean().sort_values(ascending=False).index
# Out:
# Index(['Human (2015)', 'Che: Part One (2008)', 'Che: Part Two (2008)',
#        'Brother (Brat) (1997)', 'Battle For Sevastopol (2015)',
#        'Scooby-Doo! and the Samurai Sword (2009)',
#        'Scooby-Doo! and the Loch Ness Monster (2004)',
#        'Battle Royale 2: Requiem (Batoru rowaiaru II: Chinkonka) (2003)',
#        'Justice League: Doom (2012) ', 'Meantime (1984)',
#        ...
#        'This Property is Condemned (1966)', 'Thousand Clowns, A (1965)',
#        'Tilt (2011)', 'Too Late for Tears (1949)', 'Trippin' (1999)',
#        'Venom (1982)', 'Villain (1971)', 'War Dance (2007)',
#        'Woman Is a Woman, A (femme est une femme, Une) (1961)',
#        'Young Victoria, The (2009)'],
#       dtype='object', length=9719)

# %%
min_ratings = ratings.loc[ratings.T.notna().sum().sort_values(ascending=False) > 250]

# %%
min_ratings.shape
# Out:
# (104, 9719)

# %%
min_ratings.mean().sort_values(ascending=False)
# Out:
# Girls About Town (1931)                                   5.0
# After Life (Wandafuru raifu) (1998)                       5.0
# Satin Rouge (2002)                                        5.0
# Hollywood Chainsaw Hookers (1988)                         5.0
# Hollywood Shuffle (1987)                                  5.0
#                                                          ...
# Young Poisoner's Handbook, The (1995)                     NaN
# Young Victoria, The (2009)                                NaN
# Zoom (2006)                                               NaN
# anohana: The Flower We Saw That Day - The Movie (2013)    NaN
# À nous la liberté (Freedom for Us) (1931)                 NaN
# Length: 9719, dtype: float64
